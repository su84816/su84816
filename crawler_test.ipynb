# %% [markdown]
# <a href="https://colab.research.google.com/github/su84816/su84816/blob/main/crawler_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import 套件,colab已經裝好了
import requests
import pandas as pd
import json

# %%
#目標url
#######################ask：原網址為滾動式換頁，非手動換頁的狀況下，page是否有效?
url = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=iphone13%20pro&page={page}&sort=sale/dc'
#原本網址去抓：https://ecshweb.pchome.com.tw/search/v3.3/?q=iphone13%20pro 用f12>ctrl+f>找關鍵字>找到關鍵字在網站架構下,找到url的tittle
#目標url:https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=iphone13%20pro&page=1&sort=sale/dc
#https://ecshweb.pchome.com.tw/search/v3.3/?q=ipad

# %%
#要看網站結構的用法當作法
res = requests.get(url)

# %%
#測試是否成功,只要狀態碼是2開頭就會成功
res.ok
# Out:
# False

# %%
print(res)
# Out:
# <Response [400]>

# %%
#看網站結構及存取的型態,取出關鍵值,
#可以用try except來抓錯
for i in range(1,10):
  print(f'-----------------------{i}----------------------------')
  print(url.format(page=i))
  res = requests.get(url.format(page=i))
  pchome = res.json() #內建可以讀json的排版
  for prod in pchome['prods']:
    print(prod['name'])
# Out:
# -----------------------1----------------------------
# https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=iphone13%20pro&page=1&sort=sale/dc
# 美國魚骨 SwitchEasy iPhone 13 Pro 6.1吋 ALOS lite 防摔透明保護殼(一年泛黃換新)
# (2片組)iPhone 13/ iPhone 13 Pro 6.1吋強化硬度鋼化玻璃保護貼膜
# UAG iPhone 13 Pro Max 耐衝擊保護殼-全透明
# 【犀牛盾】iPhone 13 Pro (6.1吋) Mod NX 防摔邊框背蓋兩用手機保護殼(多色可選)
# 美國魚骨 SwitchEasy iPhone13 Pro Max 6.7吋 ALOS lite 防摔透明保護殼(一年泛黃換新)
# 【犀牛盾】iPhone 13 Pro Max (6.7吋) SolidSuit 防摔背蓋手機保護殼-碳纖維紋路
# 【極致薄手機殼】iPhone 13 Pro Max / i13 Pro Max 保護殼 手機套 軟殼 保護套
# UAG iPhone 13 Pro 耐衝擊保護殼-全透明
# 【犀牛盾】iPhone 13 Pro (6.1吋) SolidSuit 經典防摔背蓋手機保護殼(多色可選)
# 【TOTU】iPhone 13 Pro / i13 Pro Max 鏡頭貼 保護貼 鋼化玻璃膜 鋁合金一體式  鎧甲系列
# 【極致薄手機殼】iPhone 13 Pro / i13 Pro 保護殼 手機套 軟殼 保護套
# Skinarma 日本潮牌 Taito 變色彩虹抗指紋防摔手機殼 透黑 iPhone 13 Pro Max (6.7 吋)
# 美國魚骨 SwitchEasy iPhone 13 Pro 6.1吋 AERO Plus 超薄防摔保護殼 霧透黑(支援MagSafe)
# iPhone 13 Pro MagSafe 透明保護殼
# iGlaze XT for iPhone 13 Pro 超薄透亮保護殼
# 美國魚骨 SwitchEasy iPhone 13 Pro 6.1吋 0.35 超薄裸機保護殼 透黑(支援MagSafe)
# ...

# %%
#pd裡面的漂亮表格
pd.DataFrame(pchome['prods'])
# Out:
#                   Id  cateId  ... couponActid  BU
# 0   DYARIZ-A900BS9VX  DYARIZ  ...          []  ec
# 1   DYARCH-A900BTUP8  DYARCH  ...          []  ec
# 2   DYAZ6G-A900BR6RY  DYAZ6G  ...          []  ec
# 3   DYARIZ-A900BQUUX  DYARIZ  ...          []  ec
# 4   DYARCH-A900BQZIF  DYARCH  ...          []  ec
# 5   DYARCH-A900BS2DB  DYARCH  ...          []  ec
# 6   DYARIZ-A900BQ4BB  DYARCH  ...          []  ec
# 7   DYARCH-A900BSAET  DYARCH  ...          []  ec
# 8   DYAZ6G-A900BQWPS  DYAZ6G  ...          []  ec
# 9   DYAZ6D-A900BS0JY  DYAZ6D  ...          []  ec
# 10  DYARCH-A900BS9NR  DYARCH  ...          []  ec
# 11  DYARIZ-A900BS8LT  DYARIZ  ...          []  ec
# 12  DYARIZ-A900BSGJQ  DYARIZ  ...          []  ec
# 13  DYARGC-A900BRU4G  DYAZ6G  ...          []  ec
# 14  DYARCH-A900BS7MQ  DYARCH  ...          []  ec
# 15  DYAZ6D-A900BRZQZ  DYAZ6D  ...          []  ec
# 16  DYARCH-A900BQVE7  DYARCH  ...          []  ec
# 17  DYARCH-A900BS0T2  DYARNS  ...          []  ec
# ...
